# %%
import pandas as pd

# Read in file
df = pd.read_csv('data/wetlands_seasonal_bird_diversity.csv')

# Check the first 5 rows
df.head()
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0  2010        39.0        40.0      50.0        45.0         NaN      61.0
# 1  2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         NaN        75.0      85.0         NaN         NaN      81.0
# 1        78.0        74.0       NaN        67.0        70.0       NaN
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0

# %%
# Default plot(): one line plot per column with numeric data
df.plot()
# Out:
# <Axes: >

# %%
# df.plot(x='x_values_column', y='y_values_column')

# %%
# Birds species registered during winter at CSM yearly
df.plot(x='year', y='CSM_winter')
# Out:
# <Axes: xlabel='year'>

# %%
df.plot(x='year', 
        y='CSM_winter',
        title='Bird species registered during spring at Carpinteria Salt Marsh',
        xlabel='Year',
        ylabel='Number of bird species',
        color='green',
        legend=False
        )
# Out:
# <Axes: title={'center': 'Bird species registered during spring at Carpinteria Salt Marsh'}, xlabel='Year', ylabel='Number of bird species'>

# %% [markdown]
# # Check in
# Plot a graph of the spring bird surveys at Mugu Lagoon with respect to the years. Include some basic customization.
#
# Use the isna() method for pandas.Series and row selection to select the rows in which Mugu Lagoon has NAs during the spring survey.

# %%
# Plot a graph of the spring bird surveys, with basic customization
df.plot(x='year', 
        y='MUL_spring',
        title='Bird species registered during spring',
        xlabel='Year',
        ylabel='Number of bird species',
        color='red',
        legend=False
        )
# Out:
# <Axes: title={'center': 'Bird species registered during spring'}, xlabel='Year', ylabel='Number of bird species'>

# %%
# Select the rows in which Mugu Lagoon has NAs
df['MUL_spring'].isna()
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# Name: MUL_spring, dtype: bool

# %%
df[df['MUL_spring'].isna()]
# Out:
#     year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0   2010        39.0        40.0      50.0        45.0         NaN      61.0
# 10  2020        46.0         NaN      47.0        56.0         NaN      66.0
#
#     SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0          NaN        75.0      85.0         NaN         NaN      81.0
# 10        57.0         NaN      58.0        54.0        40.0      54.0

# %%
df.plot(x='year', 
        y=['TJE_spring', 'TJE_fall'],
        title = 'Seasonal bird surveys at Tijuana Estuary',
        xlabel='Year',
        ylabel='Number of bird species',        
        color = {'TJE_spring':'#F48FB1',
                 'TJE_fall': '#AB47BC'
                 }
        )
# Out:
# <Axes: title={'center': 'Seasonal bird surveys at Tijuana Estuary'}, xlabel='Year', ylabel='Number of bird species'>

# %%
df.plot(x='year', 
        y=['TJE_spring', 'TJE_fall'],
        title = 'Seasonal bird surveys at Tijuana Estuary',
        xlabel='Year',
        ylabel='Number of bird species',        
        color = {'TJE_spring':'#F48FB1',
                 'TJE_fall': '#AB47BC'
                 },
        subplots=True
        )
# Out:
# array([<Axes: xlabel='Year', ylabel='Number of bird species'>,
#        <Axes: xlabel='Year', ylabel='Number of bird species'>],
#       dtype=object)

# %%
# Updating the index, general syntex
# df = df.set_index(new_index)

# %%
# Set `column_name` column in df as the new index (reassignment)
# df = df.set_index('column_name')

# %%
# Set `column_name` column in df as the new index (modify df in-place)
# df.set_index('column_name', inplace=True)

# %%
# Update index to be the year column
df = df.set_index('year')
df.head()
# Out:
#       CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# year
# 2010        39.0        40.0      50.0        45.0         NaN      61.0
# 2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2012        51.0        43.0      49.0        57.0        58.0      53.0
# 2013        42.0        46.0      38.0        60.0        58.0      62.0
# 2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#       SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# year
# 2010         NaN        75.0      85.0         NaN         NaN      81.0
# 2011        78.0        74.0       NaN        67.0        70.0       NaN
# 2012        71.0        72.0      73.0        70.0        63.0      69.0
# 2013        69.0        70.0      70.0        69.0        74.0      64.0
# 2014        61.0        78.0      71.0        60.0        81.0      62.0

# %%
# Simple plot of Carpinteria Salt Marsh winter surveys
df.plot(y='CSM_winter')
# Out:
# <Axes: xlabel='year'>

# %%
df = df.reset_index()
df.head()
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0  2010        39.0        40.0      50.0        45.0         NaN      61.0
# 1  2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         NaN        75.0      85.0         NaN         NaN      81.0
# 1        78.0        74.0       NaN        67.0        70.0       NaN
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0

# %% [markdown]
# # Check-in
# 1. Without running the code, give a step-by-step breakdown of what this code is doing:
# df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()
#
# 2. Is this code modifying the data frame df? Why or why not?
#
# 3. Run the code and examine the graph. Review the data description. Do we have all the necessary information to make sure it makes sense to directly compare the surveys at these different sites?

# %% [markdown]
# 1. Set the index to the 'year' column, use .loc to filter the dataset by selecting the columns between SDW_winter and TJE_fall, and finally use .plot to create the graph of the filtered dataset.

# %% [markdown]
# 2. No, it doesn’t, because it doesn’t have inplace=True

# %% [markdown]
# 3. We can observe a general trend, showing a decrease across all sites and seasons over the years.

# %%
df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
(df.set_index('year')
  .loc[:,'SDW_winter':'TJE_fall']
  .plot()
)
# Out:
# <Axes: xlabel='year'>

# %%
year_index_df = df.set_index('year')
subset_df = year_index_df.loc[:,'SDW_winter':'TJE_fall']
subset_df.plot()
# Out:
# <Axes: xlabel='year'>

# %%
# Read in data
URL = 'https://raw.githubusercontent.com/allisonhorst/palmerpenguins/main/inst/extdata/penguins.csv'
penguins = pd.read_csv(URL)

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
# Check column data types and NA values
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
# Simple statistics about numeric columns
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
# Count unique values in categorical columns and year
penguins[['species', 'island', 'sex', 'year']].nunique()
# Out:
# species    3
# island     3
# sex        2
# year       3
# dtype: int64

# %%
# Get unique values in species column
penguins['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
# Number of values per unique value in species column
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins.plot(kind='scatter',
              x='flipper_length_mm', 
              y='body_mass_g')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
penguins.plot(kind='scatter',
              x='flipper_length_mm', 
              y='body_mass_g',
              title='Flipper length and body mass for Palmer penguins',
              xlabel='Flipper length (mm)',
              ylabel='Body mass (g)',
              color='#ff3b01',
              alpha=0.4  # Controls transparency
              )
# Out:
# <Axes: title={'center': 'Flipper length and body mass for Palmer penguins'}, xlabel='Flipper length (mm)', ylabel='Body mass (g)'>

# %%
smallest = penguins['body_mass_g'].nsmallest(10)
smallest
# Out:
# 314    2700.0
# 58     2850.0
# 64     2850.0
# 54     2900.0
# 98     2900.0
# 116    2900.0
# 298    2900.0
# 104    2925.0
# 47     2975.0
# 44     3000.0
# Name: body_mass_g, dtype: float64

# %%
smallest.plot(kind='bar')
# Out:
# <Axes: >

# %%
penguins.nsmallest(10, 'body_mass_g')
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 314  Chinstrap      Dream            46.9           16.6              192.0
# 58      Adelie     Biscoe            36.5           16.6              181.0
# 64      Adelie     Biscoe            36.4           17.1              184.0
# 54      Adelie     Biscoe            34.5           18.1              187.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 116     Adelie  Torgersen            38.6           17.0              188.0
# 298  Chinstrap      Dream            43.2           16.6              187.0
# 104     Adelie     Biscoe            37.9           18.6              193.0
# 47      Adelie      Dream            37.5           18.9              179.0
# 44      Adelie      Dream            37.0           16.9              185.0
#
#      body_mass_g     sex  year
# 314       2700.0  female  2008
# 58        2850.0  female  2008
# 64        2850.0  female  2008
# 54        2900.0  female  2008
# 98        2900.0  female  2008
# 116       2900.0  female  2009
# 298       2900.0  female  2007
# 104       2925.0  female  2009
# 47        2975.0     NaN  2007
# 44        3000.0  female  2007

# %%
# Using plot without subsetting data - a mess again
penguins.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Distribution of flipper length measurements
# First select data, then plot
penguins['flipper_length_mm'].plot(kind='hist',
                                title='Penguin flipper lengths',
                                xlabel='Flipper length (mm)',
                                grid=True)
# Out:
# <Axes: title={'center': 'Penguin flipper lengths'}, xlabel='Flipper length (mm)', ylabel='Frequency'>

# %% [markdown]
# # Check-in
# 1. Select the bill_length_mm and bill_depth_mm columns in the penguins dataframe and then update the kind parameter to box to make boxplots of the bill length and bill depth.
#
# 2. Create a simple histogram of the flipper length of female gentoo penguins.

# %%
# Create a boxplot summarizing penguin bill measurements
# First select data, then plot
penguins[['bill_length_mm', 'bill_depth_mm']].plot(kind='box',
                                title='Penguin Bill Length and Depth Measurements',
                                xlabel='Bill Measurements (mm)',
                                grid=True,
                                color="orange")
# Out:
# <Axes: title={'center': 'Penguin Bill Length and Depth Measurements'}, xlabel='Bill Measurements (mm)'>

# %%
# Flipper length of female gentoo penguins
female_gentoos = penguins[(penguins['sex']=='female')&(penguins['species']=='Gentoo')]

female_gentoos['flipper_length_mm'].plot(kind = 'hist',
                                        title='Female gentoo penguins distribution')
# Out:
# <Axes: title={'center': 'Female gentoo penguins distribution'}, ylabel='Frequency'>

# %%
penguins.loc[(penguins['sex']=='female') & (peguins['species']=='Gentoo'), ['flipper_length_mm'].plot(kind='hist')
# Out:
#   Cell In[45], line 1
#     penguins.loc[(penguins['sex']=='female') & (peguins['species']=='Gentoo'), ['flipper_length_mm'].plot(kind='hist')
#                                                                                                                       ^
# SyntaxError: incomplete input
